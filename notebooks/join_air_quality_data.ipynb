# %%
import polars as pl

# %%
raw = pl.read_csv("../data/raw_data/2026_04_Abril_qualitat_aire_BCN.csv")
raw
# Out:
# shape: (2_370, 57)
# ┌────────────────┬───────────┬───────────────┬───────────┬───┬─────┬─────┬─────┬─────┐
# │ CODI_PROVINCIA ┆ PROVINCIA ┆ CODI_MUNICIPI ┆ MUNICIPI  ┆ … ┆ H23 ┆ V23 ┆ H24 ┆ V24 │
# │ ---            ┆ ---       ┆ ---           ┆ ---       ┆   ┆ --- ┆ --- ┆ --- ┆ --- │
# │ i64            ┆ str       ┆ i64           ┆ str       ┆   ┆ str ┆ str ┆ str ┆ str │
# ╞════════════════╪═══════════╪═══════════════╪═══════════╪═══╪═════╪═════╪═════╪═════╡
# │ 8              ┆ Barcelona ┆ 19            ┆ Barcelona ┆ … ┆ 1   ┆ V   ┆ 1   ┆ V   │
# │ 8              ┆ Barcelona ┆ 19            ┆ Barcelona ┆ … ┆ 1   ┆ V   ┆ 1   ┆ V   │
# │ 8              ┆ Barcelona ┆ 19            ┆ Barcelona ┆ … ┆ 1   ┆ V   ┆ 1   ┆ V   │
# │ 8              ┆ Barcelona ┆ 19            ┆ Barcelona ┆ … ┆ 1   ┆ V   ┆ 2   ┆ V   │
# │ 8              ┆ Barcelona ┆ 19            ┆ Barcelona ┆ … ┆ 1   ┆ V   ┆ 1   ┆ V   │
# │ …              ┆ …         ┆ …             ┆ …         ┆ … ┆ …   ┆ …   ┆ …   ┆ …   │
# ...

# %%
metadata = pl.read_csv("../data/raw_data/2026_qualitat_aire_estacions.csv")
metadata
# Out:
# shape: (71, 15)
# ┌─────────┬─────────────┬───────────┬─────┬───┬─────────────┬────────┬─────────┬───────────────────┐
# │ Estacio ┆ nom_cabina  ┆ codi_dtes ┆ zqa ┆ … ┆ Nom_barri   ┆ Clas_1 ┆ Clas_2  ┆ Codi_Contaminant  │
# │ ---     ┆ ---         ┆ ---       ┆ --- ┆   ┆ ---         ┆ ---    ┆ ---     ┆ ---               │
# │ i64     ┆ str         ┆ str       ┆ i64 ┆   ┆ str         ┆ str    ┆ str     ┆ i64               │
# ╞═════════╪═════════════╪═══════════╪═════╪═══╪═════════════╪════════╪═════════╪═══════════════════╡
# │ 4       ┆ Barcelona - ┆ I2        ┆ 1   ┆ … ┆ el Poblenou ┆ Urbana ┆ Fons    ┆ 8                 │
# │         ┆ Poblenou    ┆           ┆     ┆   ┆             ┆        ┆         ┆                   │
# │ 4       ┆ Barcelona - ┆ I2        ┆ 1   ┆ … ┆ el Poblenou ┆ Urbana ┆ Fons    ┆ 10                │
# │         ┆ Poblenou    ┆           ┆     ┆   ┆             ┆        ┆         ┆                   │
# ...

# %%
j = raw.join(
    metadata,
    on="codi_dtes"
    how="inner"
)

# %%
accidents = pl.read_csv("../data/raw_data/2025_accidents_gu_bcn.csv")

# %%
accidents
# Out:
# shape: (7_741, 25)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Numero_ex ┆ Codi_dist ┆ Nom_distr ┆ Codi_barr ┆ … ┆ Coordenad ┆ Coordenad ┆ Longitud_ ┆ Latitud_ │
# │ pedient   ┆ ricte     ┆ icte      ┆ i         ┆   ┆ a_UTM_Y_E ┆ a_UTM_X_E ┆ WGS84     ┆ WGS84    │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ D50       ┆ D50       ┆ ---       ┆ ---      │
# │ str       ┆ i64       ┆ str       ┆ i64       ┆   ┆ ---       ┆ ---       ┆ f64       ┆ f64      │
# │           ┆           ┆           ┆           ┆   ┆ f64       ┆ f64       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2025S0000 ┆ 3         ┆ Sants-Mon ┆ 11        ┆ … ┆ 429920.02 ┆ 4.5795e6  ┆ 2.1609994 ┆ 41.36198 │
# │ 01        ┆           ┆ tjuïc     ┆           ┆   ┆ 5         ┆           ┆           ┆ 1        │
# ...

# %%
obres = pl.read_json("../data/raw_data/obres_espai_public.csv")
