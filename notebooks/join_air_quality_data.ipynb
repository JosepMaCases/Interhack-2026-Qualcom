# %%
import polars as pl

# %%
raw = pl.read_csv("../data/raw_data/2026_04_Abril_qualitat_aire_BCN.csv")
raw
# Out:
# shape: (2_370, 57)
# ┌────────────────┬───────────┬───────────────┬───────────┬───┬─────┬─────┬─────┬─────┐
# │ CODI_PROVINCIA ┆ PROVINCIA ┆ CODI_MUNICIPI ┆ MUNICIPI  ┆ … ┆ H23 ┆ V23 ┆ H24 ┆ V24 │
# │ ---            ┆ ---       ┆ ---           ┆ ---       ┆   ┆ --- ┆ --- ┆ --- ┆ --- │
# │ i64            ┆ str       ┆ i64           ┆ str       ┆   ┆ str ┆ str ┆ str ┆ str │
# ╞════════════════╪═══════════╪═══════════════╪═══════════╪═══╪═════╪═════╪═════╪═════╡
# │ 8              ┆ Barcelona ┆ 19            ┆ Barcelona ┆ … ┆ 1   ┆ V   ┆ 1   ┆ V   │
# │ 8              ┆ Barcelona ┆ 19            ┆ Barcelona ┆ … ┆ 1   ┆ V   ┆ 1   ┆ V   │
# │ 8              ┆ Barcelona ┆ 19            ┆ Barcelona ┆ … ┆ 1   ┆ V   ┆ 1   ┆ V   │
# │ 8              ┆ Barcelona ┆ 19            ┆ Barcelona ┆ … ┆ 1   ┆ V   ┆ 2   ┆ V   │
# │ 8              ┆ Barcelona ┆ 19            ┆ Barcelona ┆ … ┆ 1   ┆ V   ┆ 1   ┆ V   │
# │ …              ┆ …         ┆ …             ┆ …         ┆ … ┆ …   ┆ …   ┆ …   ┆ …   │
# ...
